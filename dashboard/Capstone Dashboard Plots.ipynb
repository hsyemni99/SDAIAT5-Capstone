# %%
import pandas as pd
import plotly.express as px

# %%
tb_df = pd.read_csv("cause_of_deaths.csv")
tb_df.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
tb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
tb_df.describe().T
# Out:
#                                              count          mean  \
# Year                                        6120.0   2004.500000
# Meningitis                                  6120.0   1719.701307
# Alzheimer's Disease and Other Dementias     6120.0   4864.189379
# Parkinson's Disease                         6120.0   1173.169118
# Nutritional Deficiencies                    6120.0   2253.600000
# Malaria                                     6120.0   4140.960131
# Drowning                                    6120.0   1683.333170
# Interpersonal Violence                      6120.0   2083.797222
# Maternal Disorders                          6120.0   1262.589216
# HIV/AIDS                                    6120.0   5941.898529
# Drug Use Disorders                          6120.0    434.006699
# Tuberculosis                                6120.0   7491.928595
# Cardiovascular Diseases                     6120.0  73160.454575
# ...

# %%
tb_df.duplicated().sum()
# Out:
# 0

# %%
tb_df.isna().sum().sum()
# Out:
# 0

# %%
tb_df["Country/Territory"].value_counts().unique
# Out:
# <bound method Series.unique of Country/Territory
# Afghanistan         30
# Papua New Guinea    30
# Niue                30
# North Korea         30
# North Macedonia     30
#                     ..
# Greenland           30
# Grenada             30
# Guam                30
# Guatemala           30
# Zimbabwe            30
# Name: count, Length: 204, dtype: int64>

# %%
[tb_df[["Country/Territory"]=="Saudi Arabia"]]

# %%
grouped_by_year = tb_df.groupby(["Year"]).sum()

# %%
deathratesbyyear= grouped_by_year.drop(['Country/Territory','Code'], axis=1)
deathratesbyyear.sample(5)
# Out:
#       Meningitis  Alzheimer's Disease and Other Dementias  \
# Year
# 2011      312733                                  1201138
# 2000      385994                                   786615
# 1994      413799                                   652176
# 1999      390136                                   761620
# 2009      336868                                  1109405
#
#       Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# Year
# 2011               284488                    314327   868564    281106
# 2000               198545                    568454   882055    387627
# 1994               164381                    649801   855671    443350
# 1999               191538                    593417   893788    397169
# 2009               267738                    322879   917796    296871
#
#       Interpersonal Violence  Maternal Disorders  HIV/AIDS  \
# Year
# 2011                  413880              234669   1283719
# ...

# %%
top_causes = deathratesbyyear.sum().sort_values(ascending=False).head(10)

fig = px.bar(top_causes, x=top_causes.index, y=top_causes.values, labels={'x': 'Causes of Death', 'y': 'Number of Deaths'})
fig.update_layout(title='Top 10 Causes of Death (1990-2019)', xaxis_title='Causes of Death', yaxis_title='Number of Deaths')

fig.show()
# Out:
# <div>                            <div id="f5eff904-6106-4af4-bdb1-6585b244f054" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5eff904-6106-4af4-bdb1-6585b244f054")) {                    Plotly.newPlot(                        "f5eff904-6106-4af4-bdb1-6585b244f054",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}\u003cbr\u003eNumber of Deaths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cardiovascular Diseases","Neoplasms","Chronic Respiratory Diseases","Lower Respiratory Infections","Neonatal Disorders","Diarrheal Diseases","Digestive Diseases","Tuberculosis",
# ...

# %%
fig = px.line(data_frame=deathratesbyyear, x=deathratesbyyear.index, y="Tuberculosis")
fig.show()
# Out:
# <div>                            <div id="242b9767-4db9-474c-9ceb-5b345fc2fb1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("242b9767-4db9-474c-9ceb-5b345fc2fb1b")) {                    Plotly.newPlot(                        "242b9767-4db9-474c-9ceb-5b345fc2fb1b",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eTuberculosis=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[1776727,1786389,1807740,1774711,1753811,1738
# ...

# %%
highest_tuberculosis_deaths = deathratesbyyear['Tuberculosis'].idxmax()

highest_tuberculosis_deaths_data = deathratesbyyear.loc[highest_tuberculosis_deaths]

# Print or display the result
print("Year with the highest Tuberculosis deaths:", highest_tuberculosis_deaths)
print("\nDetails:")
print(highest_tuberculosis_deaths_data)
# Out:
# Year with the highest Tuberculosis deaths: 1992
#
# Details:
# Meningitis                                      426440
# Alzheimer's Disease and Other Dementias         605894
# Parkinson's Disease                             154886
# Nutritional Deficiencies                        700664
# Malaria                                         856415
# Drowning                                        447056
# Interpersonal Violence                          407176
# Maternal Disorders                              299300
# HIV/AIDS                                        540070
# Drug Use Disorders                               66826
# Tuberculosis                                   1807740
# Cardiovascular Diseases                       12437979
# Lower Respiratory Infections                   3258792
# Neonatal Disorders                             2950376
# Alcohol Use Disorders                           131665
# Self-harm                                       770286
# ...

# %%
fig = px.line(tb_df, x='Year', y='Tuberculosis', color='Country/Territory', title='Tuberculosis Deaths Over Time')
fig.show()
# Out:
# <div>                            <div id="14a7fbdd-d740-4081-9fd8-25935f08f59c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14a7fbdd-d740-4081-9fd8-25935f08f59c")) {                    Plotly.newPlot(                        "14a7fbdd-d740-4081-9fd8-25935f08f59c",                        [{"hovertemplate":"Country\u002fTerritory=Afghanistan\u003cbr\u003eYear=%{x}\u003cbr\u003eTuberculosis=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x
# ...

# %%
top_countries_tuberculosis = tb_df.groupby('Country/Territory')['Tuberculosis'].sum().sort_values(ascending=False).head(10)
fig = px.bar(top_countries_tuberculosis, x=top_countries_tuberculosis.index, y=top_countries_tuberculosis.values, title='Top 10 Countries with Tuberculosis Deaths')
fig.show()
# Out:
# <div>                            <div id="f6c86002-0038-4c51-ae9d-bf8026e410b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6c86002-0038-4c51-ae9d-bf8026e410b8")) {                    Plotly.newPlot(                        "f6c86002-0038-4c51-ae9d-bf8026e410b8",                        [{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["India","Indonesia","China","Pakistan","Nigeria","Ethiopia","Democratic Republic of Congo","Bangladesh","Myanmar","Philippines"],"xaxis":"x","y":[15820922,3197011,2708461,23097
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tb_deaths_by_country_year = tb_df.pivot_table(values='Tuberculosis', index='Country/Territory', columns='Year', aggfunc='sum')
plt.figure(figsize=(15, 12))
sns.heatmap(tb_deaths_by_country_year, cmap='YlGnBu', linewidths=.5)
plt.title('Tuberculosis Deaths by Country and Year')
plt.show()

# %%
import pandas as pd
pn = pd.read_csv("pneumonia-and-lower-respiratory-diseases-deaths_saudi_arabia.csv")
pn
# Out:
#           Entity Code  Year  Under 5  5-14 years  15-49 years  50-69 years  \
# 0   Saudi Arabia  SAU  1990      676         101          477          627
# 1   Saudi Arabia  SAU  1991      652         105          498          664
# 2   Saudi Arabia  SAU  1992      628         106          512          698
# 3   Saudi Arabia  SAU  1993      604         106          524          736
# 4   Saudi Arabia  SAU  1994      570         106          540          777
# 5   Saudi Arabia  SAU  1995      545         107          557          814
# 6   Saudi Arabia  SAU  1996      490         105          572          850
# 7   Saudi Arabia  SAU  1997      444         102          583          879
# 8   Saudi Arabia  SAU  1998      404          99          594          906
# 9   Saudi Arabia  SAU  1999      371          96          612          935
# 10  Saudi Arabia  SAU  2000      335          93          628          964
# ...

# %%
pn.groupby("Entity")[['Under 5','5-14 years','15-49 years','50-69 years','70+ years']].sum()
# Out:
#               Under 5  5-14 years  15-49 years  50-69 years  70+ years
# Entity
# Saudi Arabia     8321        2194        27450        35448      35249

# %%
import pandas as pd
data_tb = pd.read_csv('cause_of_deaths.csv')
saudi_data = data_tb[data_tb['Country/Territory'] == 'Saudi Arabia']
deathratesbyyear = saudi_data.groupby(["Year"]).sum()
deathratesbyyear = deathratesbyyear.drop(['Country/Territory', 'Code'], axis=1)
top_causes = deathratesbyyear.sum().sort_values(ascending=False).head(15)

# %%
top_causes
# Out:
# Cardiovascular Diseases                       982797
# Road Injuries                                 403385
# Neoplasms                                     239941
# Neonatal Disorders                            147215
# Chronic Kidney Disease                        137413
# Digestive Diseases                            119165
# Lower Respiratory Infections                  108663
# Chronic Respiratory Diseases                   93099
# Cirrhosis and Other Chronic Liver Diseases     92019
# Diabetes Mellitus                              65129
# Tuberculosis                                   48535
# Alzheimer's Disease and Other Dementias        35620
# Self-harm                                      26827
# Diarrheal Diseases                             24024
# Drowning                                       18507
# dtype: int64

# %%
deathratesbyyear['Cardiovascular Diseases']
# Out:
# Year
# 1990    20459
# 1991    21321
# 1992    22120
# 1993    22940
# 1994    23788
# 1995    24622
# 1996    25386
# 1997    26132
# 1998    26922
# 1999    27798
# 2000    28588
# 2001    29427
# 2002    30307
# 2003    31361
# 2004    32373
# 2005    33754
# 2006    34953
# 2007    36026
# 2008    37081
# 2009    37703
# 2010    38274
# 2011    38295
# 2012    38504
# 2013    39159
# 2014    39738
# 2015    41019
# 2016    41765
# 2017    42897
# 2018    44248
# 2019    45837
# Name: Cardiovascular Diseases, dtype: int64
