# %% [markdown]
# ## project

# %%
import pandas as pd
from math import floor
import numpy as np
from pathlib import Path
import PIL
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory, img_to_array, array_to_img
from matplotlib import pyplot as plt

# %%
train_path =Path('dataset/train')
test_path =Path('dataset/test')
val_path = Path('dataset/validation')

# %%
image_count = (len(list(train_path.glob('*/*.*'))) + 
               len(list(test_path.glob('*/*.*'))) +
               len(list(val_path.glob('*/*.*'))))
print(image_count)
# Out:
# 7023

# %%
len(list(train_path.glob('*/*.*'))),len(list(test_path.glob('*/*.*'))),len(list(val_path.glob('*/*.*')))
# Out:
# (4914, 1054, 1055)

# %%
batch_size = 64
img_height = 128
img_width = 128

# %%
train_ds = image_dataset_from_directory(
  train_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale",
  shuffle=True)
# Out:
# Found 4914 files belonging to 4 classes.

# %%
train_ds.class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
test_ds = image_dataset_from_directory(
  test_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 1054 files belonging to 4 classes.

# %%
test_ds.class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
val_ds = image_dataset_from_directory(
  val_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  color_mode="grayscale")
# Out:
# Found 1055 files belonging to 4 classes.

# %%
val_ds.class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
num_classes = len(class_names)
num_classes
# Out:
# 4

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
class_labels_train = np.concatenate([y for x, y in train_ds], axis=0)
class_labels_train, len(class_labels_train)
# Out:
# (array([2, 1, 0, ..., 0, 2, 3]), 4914)

# %%
class_labels = np.unique(class_labels_train)
class_labels
# Out:
# array([0, 1, 2, 3])

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced', 
                                                  classes=class_labels, 
                                                  y=class_labels_train)
class_weights
# Out:
# array([1.08333333, 1.06733275, 0.8775    , 0.99959317])

# %%
class_weights_dict = {}

for idx, i in enumerate(class_weights):
    class_weights_dict[idx] = i

    
print(class_weights_dict)
# Out:
# {0: 1.0833333333333333, 1: 1.0673327541268463, 2: 0.8775, 3: 0.999593165174939}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Reshape,MaxPooling2D, Flatten, BatchNormalization, Resizing, Rescaling, Lambda, Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential()
model.add(Input(shape=(None, None, 1)))

model.add(Resizing(128, 128))
model.add(Rescaling(1./255))

model.add(Conv2D(32, (3, 3), activation='relu',))
model.add(MaxPooling2D(4,4))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['Accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 128, 128, 1)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 1)       0
#
#  conv2d (Conv2D)             (None, 126, 126, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 512)               590336
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 757,188
# Trainable params: 757,188
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint(filepath="BrainTumors.keras",
                             monitor='val_loss', save_best_only=True,
                             save_weights_only=False,
                             verbose=3)

earlystopper = EarlyStopping(monitor='val_loss', patience=4)

callbackslist = [checkpoint, earlystopper]

# %%
model.fit(train_ds, validation_data=test_ds, epochs=50, callbacks=callbackslist, class_weight=class_weights_dict)
# Out:
# Epoch 1/50
# 77/77 [==============================] - ETA: 0s - loss: 1.1601 - Accuracy: 0.4611
# Epoch 1: val_loss improved from inf to 0.72893, saving model to BrainTumors.keras
# 77/77 [==============================] - 16s 198ms/step - loss: 1.1601 - Accuracy: 0.4611 - val_loss: 0.7289 - val_Accuracy: 0.6774
# Epoch 2/50
# 77/77 [==============================] - ETA: 0s - loss: 0.7435 - Accuracy: 0.7002
# Epoch 2: val_loss improved from 0.72893 to 0.56319, saving model to BrainTumors.keras
# 77/77 [==============================] - 13s 174ms/step - loss: 0.7435 - Accuracy: 0.7002 - val_loss: 0.5632 - val_Accuracy: 0.7476
# Epoch 3/50
# 77/77 [==============================] - ETA: 0s - loss: 0.5861 - Accuracy: 0.7684
# Epoch 3: val_loss improved from 0.56319 to 0.46067, saving model to BrainTumors.keras
# 77/77 [==============================] - 14s 180ms/step - loss: 0.5861 - Accuracy: 0.7684 - val_loss: 0.4607 - val_Accuracy: 0.8254
# Epoch 4/50
# 77/77 [==============================] - ETA: 0s - loss: 0.5013 - Accuracy: 0.8095
# Epoch 4: val_loss improved from 0.46067 to 0.42470, saving model to BrainTumors.keras
# 77/77 [==============================] - 14s 185ms/step - loss: 0.5013 - Accuracy: 0.8095 - val_loss: 0.4247 - val_Accuracy: 0.8416
# Epoch 5/50
# 77/77 [==============================] - ETA: 0s - loss: 0.4361 - Accuracy: 0.8460
# Epoch 5: val_loss improved from 0.42470 to 0.36521, saving model to BrainTumors.keras
# 77/77 [==============================] - 16s 203ms/step - loss: 0.4361 - Accuracy: 0.8460 - val_loss: 0.3652 - val_Accuracy: 0.8558
# Epoch 6/50
# 77/77 [==============================] - ETA: 0s - loss: 0.3637 - Accuracy: 0.8669
# Epoch 6: val_loss improved from 0.36521 to 0.31231, saving model to BrainTumors.keras
# 77/77 [==============================] - 15s 200ms/step - loss: 0.3637 - Accuracy: 0.8669 - val_loss: 0.3123 - val_Accuracy: 0.8776
# Epoch 7/50
# 77/77 [==============================] - ETA: 0s - loss: 0.3336 - Accuracy: 0.8814
# Epoch 7: val_loss improved from 0.31231 to 0.28036, saving model to BrainTumors.keras
# 77/77 [==============================] - 15s 191ms/step - loss: 0.3336 - Accuracy: 0.8814 - val_loss: 0.2804 - val_Accuracy: 0.8899
# Epoch 8/50
# 77/77 [==============================] - ETA: 0s - loss: 0.2783 - Accuracy: 0.9042
# Epoch 8: val_loss did not improve from 0.28036
# 77/77 [==============================] - 14s 178ms/step - loss: 0.2783 - Accuracy: 0.9042 - val_loss: 0.3415 - val_Accuracy: 0.8738
# Epoch 9/50
# 77/77 [==============================] - ETA: 0s - loss: 0.2621 - Accuracy: 0.9042
# Epoch 9: val_loss improved from 0.28036 to 0.24015, saving model to BrainTumors.keras
# 77/77 [==============================] - 13s 174ms/step - loss: 0.2621 - Accuracy: 0.9042 - val_loss: 0.2402 - val_Accuracy: 0.9156
# Epoch 10/50
# 77/77 [==============================] - ETA: 0s - loss: 0.2428 - Accuracy: 0.9145
# Epoch 10: val_loss did not improve from 0.24015
# 77/77 [==============================] - 13s 172ms/step - loss: 0.2428 - Accuracy: 0.9145 - val_loss: 0.2653 - val_Accuracy: 0.9165
# Epoch 11/50
# Epoch 21/50
# 77/77 [==============================] - ETA: 0s - loss: 0.0668 - Accuracy: 0.9790
# Epoch 21: val_loss did not improve from 0.19966
# 77/77 [==============================] - 13s 175ms/step - loss: 0.0668 - Accuracy: 0.9790 - val_loss: 0.3178 - val_Accuracy: 0.9345

# %%
train_loss, train_acc = model.evaluate(train_ds, verbose = 0)
test_loss, test_acc = model.evaluate(test_ds, verbose = 0)
val_loss, val_acc = model.evaluate(val_ds, verbose = 0)

# %%
print("Training Accuracy: %5.2f\nTraining Loss: %5.2f \n"%(train_acc*100, train_loss))
print("Testing Accuracy: %5.2f \nTesting Loss: %5.2f \n"%(test_acc*100, test_loss))
print("Val Accuracy: %5.2f \nVal Loss: %5.2f"%(val_acc*100, val_loss))
# Out:
# Training Accuracy: 98.64
# Training Loss:  0.05
#
# Testing Accuracy: 93.45
# Testing Loss:  0.32
#
# Val Accuracy: 93.65
# Val Loss:  0.35

# %%
model.save("BrainTumorModel.keras")

# %%
# import tensorflow as tf
# tf.keras.models.save_model(model, "BrainTumorsModels.keras")

# %%
loaded_model = tf.keras.models.load_model("BrainTumors.keras")

# %%
true_y = np.concatenate([y for x, y in val_ds])
true_y, len(true_y)
# Out:
# (array([0, 3, 0, ..., 3, 1, 3]), 1055)

# %%
preds_softmax = loaded_model.predict(val_ds)
# Out:
# 17/17 [==============================] - 1s 37ms/step

# %%
preds = []
for i in preds_softmax:
    preds.append(np.argmax(i))
#del(preds_softmax)
len(preds)
# Out:
# 1055

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, cohen_kappa_score,f1_score, confusion_matrix

# %%
### print("Accuracy Score is ",accuracy_score(true_y, preds))
print("Recall Score is ",recall_score(true_y, preds, average='macro'))
print("Precision Score is ",precision_score(true_y, preds, average='macro'))
print("Cohen Kappa Score is ",cohen_kappa_score(true_y, preds))
print("F1 Score is ",f1_score(true_y, preds, average='macro'))
print("Confusion Matrix is \n",confusion_matrix(true_y, preds))

# %% [markdown]
# We need to apply the same preprocessing techniques we used for the training data to any new image.
# Here are the steps to processing new images.
# * Resize the image to be of 128x128 dimensions.
# * Convert the image to grayscale.
# * Expand image dimensions to take the following form, (batch_size, img_height, img_width, num_channels)

# %%
def prediction(image):
    image = image.convert("L")
    image = (np.expand_dims(image,0))
    predictions = loaded_model.predict(image, verbose=0)
    pred=np.argmax(predictions)
    return pred

# %%
def prediction_decode(image):
    image = image.convert("L")
    image = (np.expand_dims(image,0))
    predictions = loaded_model.predict(image, verbose=0)
    pred=np.argmax(predictions)
    return class_names[pred]

# %%
confusion_mtx = confusion_matrix(true_y, preds)
target_names = class_names
plt.figure(figsize = (8,8))
sns.heatmap(confusion_mtx,cmap= "Reds", linecolor = 'gray' , linewidth = 0.01 , annot = True, fmt='.2f' , xticklabels = target_names , yticklabels = target_names)
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

# %%
from PIL import Image
import random

# %%
class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
img=Image.open(f"dataset/validation/meningioma/Te-me_0024.jpg")
prediction(img), prediction_decode(img)
# Out:
# (1, 'meningioma')
